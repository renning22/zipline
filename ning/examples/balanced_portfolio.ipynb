# %%
# %load_ext zipline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %%zipline -b custom-csvdir-bundle --trading-calendar TWENTYFOURSEVEN --data-frequency minute --start 2017-6-1 --end 2017-7-2 -o balanced_portfolio.pickle
#
# from zipline.api import (
#     attach_pipeline,
#     date_rules,
#     order_target,
#     order_target_percent,
#     pipeline_output,
#     record,
#     schedule_function,
#     symbol,
#     set_benchmark,
#     time_rules,
# )
# from zipline.finance import commission
#
# def initialize(context):
#     set_benchmark(symbol('BTC_USD'))
#     context.set_commission(commission.PerDollar(cost=0.002))
#
#     context.i = 0
#     context.btc = symbol('BTC_USD')
#     context.eth = symbol('ETH_USD')
#     context.xrp = symbol('XRP_USD')
#
#     schedule_function(
#         func=my_rebalance,
#         date_rule=date_rules.week_start(days_offset=1),
#         time_rule=time_rules.market_close(minutes=1),
#     )
#
#     # This function was scheduled to run once per day at 11AM ET.
# def my_rebalance(context, data):
#     # print 'my_rebalance {}'.format(context.i)
#     # print 'context.portfolio.positions {}'.format(context.portfolio.positions)
#     order_target_percent(context.btc, 0.25)
#     order_target_percent(context.eth, 0.25)
#     order_target_percent(context.xrp, 0.25)
#
# def handle_data(context, data):
#     context.i += 1
# Out:
#                            algo_volatility  algorithm_period_return  alpha  \
# 2017-06-01 23:59:00+00:00         0.000000                 0.000000    0.0
# 2017-06-02 23:59:00+00:00         0.000000                 0.000000    NaN
# 2017-06-03 23:59:00+00:00         0.000000                 0.000000    NaN
# 2017-06-04 23:59:00+00:00         0.000000                 0.000000    NaN
# 2017-06-05 23:59:00+00:00         0.000000                 0.000000    NaN
# 2017-06-06 23:59:00+00:00         0.000376                -0.000058    NaN
# 2017-06-07 23:59:00+00:00         0.132301                -0.022117    NaN
# 2017-06-08 23:59:00+00:00         0.164955                -0.005956    NaN
# 2017-06-09 23:59:00+00:00         0.180924                 0.011096    NaN
# 2017-06-10 23:59:00+00:00         0.185253                 0.026950    NaN
# 2017-06-11 23:59:00+00:00         0.202299                 0.051244    NaN
# ...
