# %%
# %load_ext zipline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %%zipline -b custom-csvdir-bundle --trading-calendar TWENTYFOURSEVEN --data-frequency minute --start 2017-6-1 --end 2017-12-30 --capital-base 10000 -o balanced_and_hold.pickle
#
# from zipline.api import (
#     attach_pipeline,
#     date_rules,
#     order_target,
#     order_target_percent,
#     pipeline_output,
#     record,
#     schedule_function,
#     symbol,
#     set_benchmark,
#     time_rules,
# )
# from zipline.finance import commission
#
# def initialize(context):
#     set_benchmark(symbol('BTC_USD'))
#     context.set_commission(commission.PerDollar(cost=0.002))
#
#     context.i = 0
#     context.btc = symbol('BTC_USD')
#     context.eth = symbol('ETH_USD')
#     context.xrp = symbol('XRP_USD')
#
#
# def handle_data(context, data):
#     context.i += 1
#
#     if context.i == 1:
#         order_target_percent(context.btc, 0.25)
#         order_target_percent(context.eth, 0.25)
#         order_target_percent(context.xrp, 0.25)
# Out:
# trading_calendar1: <<extension>.TwentyFourSevenCalendar object at 0x7f0163568710>
# trading_calendar2: <<extension>.TwentyFourSevenCalendar object at 0x7f0163568710>
# self.bm_symbol: BTC_USD
# trading_calendar.day: <CustomBusinessDay>
# trading_calendar.schedule.index: DatetimeIndex(['1990-01-01', '1990-01-02', '1990-01-03', '1990-01-04',
#                '1990-01-05', '1990-01-06', '1990-01-07', '1990-01-08',
#                '1990-01-09', '1990-01-10',
#                ...
#                '2018-12-21', '2018-12-22', '2018-12-23', '2018-12-24',
#                '2018-12-25', '2018-12-26', '2018-12-27', '2018-12-28',
#                '2018-12-29', '2018-12-30'],
#               dtype='datetime64[ns, UTC]', length=10591, freq='C')
#                            algo_volatility  algorithm_period_return  \
# 2017-06-01 23:59:00+00:00         0.852449                 0.075942
# 2017-06-02 23:59:00+00:00         1.115351                 0.050742
# ...
