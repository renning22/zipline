# %%
# %load_ext zipline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %%zipline -b custom-csvdir-bundle --trading-calendar TWENTYFOURSEVEN --data-frequency minute --start 2017-6-1 --end 2017-6-2 --capital-base 10000
#
# from zipline.api import order, symbol, set_benchmark
# from zipline.finance import commission
#
# stocks = ['BTC_USD']
#
#
# def initialize(context):
#     set_benchmark(symbol('BTC_USD'))
#     context.set_commission(commission.PerDollar(cost=0.002))
#     context.has_ordered = False
#     context.stocks = stocks
#
#
# def handle_data(context, data):
#     if not context.has_ordered:
#         for stock in context.stocks:
#             order(symbol(stock), 100)
#         context.has_ordered = True
# Out:
# trading_calendar1: <<extension>.TwentyFourSevenCalendar object at 0x7fce68353d50>
# trading_calendar2: <<extension>.TwentyFourSevenCalendar object at 0x7fce68353d50>
# self.bm_symbol: BTC_USD
# trading_calendar.day: <CustomBusinessDay>
# trading_calendar.schedule.index: DatetimeIndex(['1990-01-01', '1990-01-02', '1990-01-03', '1990-01-04',
#                '1990-01-05', '1990-01-06', '1990-01-07', '1990-01-08',
#                '1990-01-09', '1990-01-10',
#                ...
#                '2019-01-03', '2019-01-04', '2019-01-05', '2019-01-06',
#                '2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10',
#                '2019-01-11', '2019-01-12'],
#               dtype='datetime64[ns, UTC]', length=10604, freq='C')
#                            algo_volatility  algorithm_period_return  \
# 2017-06-01 23:59:00+00:00         0.774381                 0.068987
# 2017-06-02 23:59:00+00:00         9.085650                 1.007987
#
# ...
